# %%
import pandas as pd
import numpy as np
np.random.seed(42)

data = {
    'NumericalFeature1': np.random.randint(0, 100, 100),
    'NumericalFeature2': np.random.randn(100) * 10 + 50,
    'CategoricalFeature1': np.random.choice(['A', 'B', 'C'], 100),
    'CategoricalFeature2': np.random.choice(['X', 'Y', 'Z'], 100),
    'TargetVariable': np.random.choice([0, 1], 100)
}
df = pd.DataFrame(data)
df
# Out:
#     NumericalFeature1  NumericalFeature2 CategoricalFeature1  \
# 0                  51          36.533219                   B
# 1                  92          41.194087                   A
# 2                  14          38.694477                   A
# 3                  71          51.344289                   B
# 4                  60          55.821228                   A
# ..                ...                ...                 ...
# 95                 84          48.390626                   B
# 96                 79          46.117356                   C
# 97                 81          41.144876                   B
# 98                 52          46.432550                   B
# 99                 23          55.561218                   C
#
#    CategoricalFeature2  TargetVariable
# 0                    Y               0
# 1                    Z               0
# 2                    Y               0
# 3                    Z               1
# 4                    Z               1
# ..                 ...             ...
# 95                   X               1
# 96                   Z               0
# 97                   Z               1
# 98                   X               1
# 99                   Y               1
#
# [100 rows x 5 columns]

# %%
from tableone import TableOne
cat = ['CategoricalFeature1', 'CategoricalFeature2']
cont = ['NumericalFeature1', 'NumericalFeature2']
tableone = TableOne(df, categorical=cat, continuous=cont, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                              │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞══════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                            │    │           │ 100         │ 45          │ 55          │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD) │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD) │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1, n (%)   │ A  │           │ 39 (39.0)   │ 19 (42.2)   │ 20 (36.4)   │ 0.822     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ B  │           │ 32 (32.0)   │ 14 (31.1)   │ 18 (32.7)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ C  │           │ 29 (29.0)   │ 12 (26.7)   │ 17 (30.9)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2, n (%)   │ X  │           │ 31 (31.0)   │ 15 (33.3)   │ 16 (29.1)   │ 0.901     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ Y  │           │ 39 (39.0)   │ 17 (37.8)   │ 22 (40.0)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ Z  │           │ 30 (30.0)   │ 13 (28.9)   │ 17 (30.9)   │           │
# ╘══════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %%
# label encode the categorical features and create a new df
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_encoded = df.copy()
for col in cat:
    df_encoded[col] = le.fit_transform(df[col])
tableone = TableOne(df_encoded, categorical=cat, continuous=cont, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                              │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞══════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                            │    │           │ 100         │ 45          │ 55          │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD) │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD) │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1, n (%)   │ 0  │           │ 39 (39.0)   │ 19 (42.2)   │ 20 (36.4)   │ 0.822     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 32 (32.0)   │ 14 (31.1)   │ 18 (32.7)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 2  │           │ 29 (29.0)   │ 12 (26.7)   │ 17 (30.9)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2, n (%)   │ 0  │           │ 31 (31.0)   │ 15 (33.3)   │ 16 (29.1)   │ 0.901     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 39 (39.0)   │ 17 (37.8)   │ 22 (40.0)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 2  │           │ 30 (30.0)   │ 13 (28.9)   │ 17 (30.9)   │           │
# ╘══════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %% [markdown]
# # label encoding does not change p-value

# %%
tableone = TableOne(df_encoded, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                                │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞════════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                              │    │           │ 100         │ 45          │ 55          │           │
# ├────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD)   │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD)   │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1, mean (SD) │    │ 0         │ 0.9 (0.8)   │ 0.8 (0.8)   │ 0.9 (0.8)   │ 0.544     │
# ├────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2, mean (SD) │    │ 0         │ 1.0 (0.8)   │ 1.0 (0.8)   │ 1.0 (0.8)   │ 0.694     │
# ╘════════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %% [markdown]
# # not specificying cat/cont variables *does* change p-value (if encoding)

# %%
import statsmodels.api as sm
sm_cols = ['C(' + col + ')' for col in cat] + cont
formula = 'TargetVariable ~ ' + ' + '.join(sm_cols)
print(sm.formula.logit(formula, data=df).fit().summary())
print(sm.formula.logit(formula, data=df_encoded).fit().summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619175
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                  0.1002
# Time:                        16:25:15   Log-Likelihood:                -61.917
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                   0.03204
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -4.8439      1.512     -3.204      0.001      -7.807      -1.881
# C(CategoricalFeature1)[T.B]     0.1958      0.523      0.374      0.708      -0.829       1.221
# C(CategoricalFeature1)[T.C]     0.3535      0.540      0.654      0.513      -0.705       1.412
# C(CategoricalFeature2)[T.Y]     0.4153      0.521      0.797      0.425      -0.605       1.436
# C(CategoricalFeature2)[T.Z]     0.5182      0.570      0.909      0.363      -0.599       1.635
# NumericalFeature1               0.0070      0.008      0.919      0.358      -0.008       0.022
# NumericalFeature2               0.0848      0.027      3.175      0.001       0.032       0.137
# ===============================================================================================
# Optimization terminated successfully.
#          Current function value: 0.619175
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                  0.1002
# Time:                        16:25:15   Log-Likelihood:                -61.917
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                   0.03204
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -4.8439      1.512     -3.204      0.001      -7.807      -1.881
# C(CategoricalFeature1)[T.1]     0.1958      0.523      0.374      0.708      -0.829       1.221
# C(CategoricalFeature1)[T.2]     0.3535      0.540      0.654      0.513      -0.705       1.412
# C(CategoricalFeature2)[T.1]     0.4153      0.521      0.797      0.425      -0.605       1.436
# C(CategoricalFeature2)[T.2]     0.5182      0.570      0.909      0.363      -0.599       1.635
# NumericalFeature1               0.0070      0.008      0.919      0.358      -0.008       0.022
# NumericalFeature2               0.0848      0.027      3.175      0.001       0.032       0.137
# ===============================================================================================

# %% [markdown]
# # using sm formula on label encoded vs non-encoded does not change p-value

# %%
X = df_encoded.drop('TargetVariable', axis=1)
Xsm = sm.add_constant(X)
y = df_encoded['TargetVariable']
sm.Logit(y, Xsm).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619794
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       95
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                 0.09932
# Time:                        16:28:15   Log-Likelihood:                -61.979
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                  0.008430
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -4.7639      1.490     -3.197      0.001      -7.684      -1.843
# NumericalFeature1       0.0066      0.007      0.886      0.376      -0.008       0.021
# NumericalFeature2       0.0847      0.027      3.176      0.001       0.032       0.137
# CategoricalFeature1     0.1842      0.269      0.686      0.493      -0.342       0.711
# CategoricalFeature2     0.2631      0.285      0.924      0.356      -0.295       0.821
# =======================================================================================
# """

# %% [markdown]
# # using sm formula vs non-formula does slightly alter p-value

# %% [markdown]
# ============================================================
# # TEST WITH ONE HOT ENCODING
# ============================================================

# %%
import pandas as pd
import numpy as np
np.random.seed(42)

data = {
    'NumericalFeature1': np.random.randint(0, 100, 100),
    'NumericalFeature2': np.random.randn(100) * 10 + 50,
    'CategoricalFeature1': np.random.choice(['A', 'B', 'C'], 100),
    'CategoricalFeature2': np.random.choice(['X', 'Y', 'Z'], 100),
    'TargetVariable': np.random.choice([0, 1], 100)
}
df = pd.DataFrame(data)
df
# Out:
#     NumericalFeature1  NumericalFeature2 CategoricalFeature1  \
# 0                  51          36.533219                   B
# 1                  92          41.194087                   A
# 2                  14          38.694477                   A
# 3                  71          51.344289                   B
# 4                  60          55.821228                   A
# ..                ...                ...                 ...
# 95                 84          48.390626                   B
# 96                 79          46.117356                   C
# 97                 81          41.144876                   B
# 98                 52          46.432550                   B
# 99                 23          55.561218                   C
#
#    CategoricalFeature2  TargetVariable
# 0                    Y               0
# 1                    Z               0
# 2                    Y               0
# 3                    Z               1
# 4                    Z               1
# ..                 ...             ...
# 95                   X               1
# 96                   Z               0
# 97                   Z               1
# 98                   X               1
# 99                   Y               1
#
# [100 rows x 5 columns]

# %%
from tableone import TableOne
cat = ['CategoricalFeature1', 'CategoricalFeature2']
cont = ['NumericalFeature1', 'NumericalFeature2']
tableone = TableOne(df, categorical=cat, continuous=cont, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                              │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞══════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                            │    │           │ 100         │ 45          │ 55          │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD) │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD) │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1, n (%)   │ A  │           │ 39 (39.0)   │ 19 (42.2)   │ 20 (36.4)   │ 0.822     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ B  │           │ 32 (32.0)   │ 14 (31.1)   │ 18 (32.7)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ C  │           │ 29 (29.0)   │ 12 (26.7)   │ 17 (30.9)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2, n (%)   │ X  │           │ 31 (31.0)   │ 15 (33.3)   │ 16 (29.1)   │ 0.901     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ Y  │           │ 39 (39.0)   │ 17 (37.8)   │ 22 (40.0)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ Z  │           │ 30 (30.0)   │ 13 (28.9)   │ 17 (30.9)   │           │
# ╘══════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %%
# one hot encode the categorical features (as integers) and create a new df
df_encoded = pd.get_dummies(df, columns=cat)
cat_encoded = [c for c in df_encoded.columns if c not in cont + ['TargetVariable']]
df_encoded[cat_encoded] = df_encoded[cat_encoded].astype(int)
tableone = TableOne(df_encoded, categorical=cat_encoded, continuous=cont, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                              │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞══════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                            │    │           │ 100         │ 45          │ 55          │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD) │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD) │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_A, n (%) │ 0  │           │ 61 (61.0)   │ 26 (57.8)   │ 35 (63.6)   │ 0.695     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 39 (39.0)   │ 19 (42.2)   │ 20 (36.4)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_C, n (%) │ 0  │           │ 71 (71.0)   │ 33 (73.3)   │ 38 (69.1)   │ 0.808     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 29 (29.0)   │ 12 (26.7)   │ 17 (30.9)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_X, n (%) │ 0  │           │ 69 (69.0)   │ 30 (66.7)   │ 39 (70.9)   │ 0.811     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 31 (31.0)   │ 15 (33.3)   │ 16 (29.1)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_Y, n (%) │ 0  │           │ 61 (61.0)   │ 28 (62.2)   │ 33 (60.0)   │ 0.984     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 39 (39.0)   │ 17 (37.8)   │ 22 (40.0)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_B, n (%) │ 0  │           │ 68 (68.0)   │ 31 (68.9)   │ 37 (67.3)   │ 1.000     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 32 (32.0)   │ 14 (31.1)   │ 18 (32.7)   │           │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_Z, n (%) │ 0  │           │ 70 (70.0)   │ 32 (71.1)   │ 38 (69.1)   │ 1.000     │
# ├──────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │                              │ 1  │           │ 30 (30.0)   │ 13 (28.9)   │ 17 (30.9)   │           │
# ╘══════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %% [markdown]
# # one hot encoding *does* change p-value

# %%
tableone = TableOne(df_encoded, groupby='TargetVariable', sort='P-Value', pval=True)
print(tableone.tabulate(tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════════╤════╤═══════════╤═════════════╤═════════════╤═════════════╤═══════════╕
# │                                  │    │ Missing   │ Overall     │ 0           │ 1           │ P-Value   │
# ╞══════════════════════════════════╪════╪═══════════╪═════════════╪═════════════╪═════════════╪═══════════╡
# │ n                                │    │           │ 100         │ 45          │ 55          │           │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature2, mean (SD)     │    │ 0         │ 50.0 (9.3)  │ 46.6 (8.9)  │ 52.8 (8.8)  │ 0.001     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ NumericalFeature1, mean (SD)     │    │ 0         │ 50.5 (29.4) │ 47.6 (31.2) │ 53.0 (28.0) │ 0.367     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_A, mean (SD) │    │ 0         │ 0.4 (0.5)   │ 0.4 (0.5)   │ 0.4 (0.5)   │ 0.556     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_C, mean (SD) │    │ 0         │ 0.3 (0.5)   │ 0.3 (0.4)   │ 0.3 (0.5)   │ 0.644     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_X, mean (SD) │    │ 0         │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.653     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_Y, mean (SD) │    │ 0         │ 0.4 (0.5)   │ 0.4 (0.5)   │ 0.4 (0.5)   │ 0.823     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature2_Z, mean (SD) │    │ 0         │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.828     │
# ├──────────────────────────────────┼────┼───────────┼─────────────┼─────────────┼─────────────┼───────────┤
# │ CategoricalFeature1_B, mean (SD) │    │ 0         │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.3 (0.5)   │ 0.865     │
# ╘══════════════════════════════════╧════╧═══════════╧═════════════╧═════════════╧═════════════╧═══════════╛

# %% [markdown]
# # not specificying cat/cont variables *does* change p-value (if encoding)

# %%
import statsmodels.api as sm
sm_cols = ['C(' + col + ')' for col in cat] + cont
formula = 'TargetVariable ~ ' + ' + '.join(sm_cols)
print(sm.formula.logit(formula, data=df).fit().summary())

sm_cols = ['C(' + col + ')' for col in cat_encoded] + cont
formula = 'TargetVariable ~ ' + ' + '.join(sm_cols)
print(sm.formula.logit(formula, data=df_encoded).fit().summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619175
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                  0.1002
# Time:                        16:51:33   Log-Likelihood:                -61.917
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                   0.03204
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -4.8439      1.512     -3.204      0.001      -7.807      -1.881
# C(CategoricalFeature1)[T.B]     0.1958      0.523      0.374      0.708      -0.829       1.221
# C(CategoricalFeature1)[T.C]     0.3535      0.540      0.654      0.513      -0.705       1.412
# C(CategoricalFeature2)[T.Y]     0.4153      0.521      0.797      0.425      -0.605       1.436
# C(CategoricalFeature2)[T.Z]     0.5182      0.570      0.909      0.363      -0.599       1.635
# NumericalFeature1               0.0070      0.008      0.919      0.358      -0.008       0.022
# NumericalFeature2               0.0848      0.027      3.175      0.001       0.032       0.137
# ===============================================================================================
# Optimization terminated successfully.
#          Current function value: 0.619175
#          Iterations 16
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                  0.1002
# Time:                        16:51:33   Log-Likelihood:                -61.917
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                   0.03204
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -2.6098   9.89e+06  -2.64e-07      1.000   -1.94e+07    1.94e+07
# C(CategoricalFeature1_A)[T.1]    -1.0530        nan        nan        nan         nan         nan
# C(CategoricalFeature1_B)[T.1]    -0.8572        nan        nan        nan         nan         nan
# C(CategoricalFeature1_C)[T.1]    -0.6995        nan        nan        nan         nan         nan
# C(CategoricalFeature2_X)[T.1]    -1.1811        nan        nan        nan         nan         nan
# C(CategoricalFeature2_Y)[T.1]    -0.7658        nan        nan        nan         nan         nan
# C(CategoricalFeature2_Z)[T.1]    -0.6629        nan        nan        nan         nan         nan
# NumericalFeature1                 0.0070      0.008      0.919      0.358      -0.008       0.022
# NumericalFeature2                 0.0848      0.027      3.175      0.001       0.032       0.137
# =================================================================================================

# %% [markdown]
# # using sm formula on label encoded vs non-encoded does not change p-value (of numerical variables)

# %%
X = df_encoded.drop('TargetVariable', axis=1)
Xsm = sm.add_constant(X)
y = df_encoded['TargetVariable']
sm.Logit(y, Xsm).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.619175
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         TargetVariable   No. Observations:                  100
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 29 Aug 2024   Pseudo R-squ.:                  0.1002
# Time:                        16:51:45   Log-Likelihood:                -61.917
# converged:                       True   LL-Null:                       -68.814
# Covariance Type:            nonrobust   LLR p-value:                   0.03204
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -2.6098   8.72e+06  -2.99e-07      1.000   -1.71e+07    1.71e+07
# NumericalFeature1         0.0070      0.008      0.919      0.358      -0.008       0.022
# NumericalFeature2         0.0848      0.027      3.175      0.001       0.032       0.137
# CategoricalFeature1_A    -1.0530        nan        nan        nan         nan         nan
# CategoricalFeature1_B    -0.8572        nan        nan        nan         nan         nan
# CategoricalFeature1_C    -0.6995        nan        nan        nan         nan         nan
# CategoricalFeature2_X    -1.1811        nan        nan        nan         nan         nan
# CategoricalFeature2_Y    -0.7658        nan        nan        nan         nan         nan
# CategoricalFeature2_Z    -0.6629        nan        nan        nan         nan         nan
# =========================================================================================
# """

# %% [markdown]
# # using sm formula vs non-formula does slightly alter p-value
